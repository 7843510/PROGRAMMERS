# %% [markdown]
# ### **🔖 두 수의 곱**

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 문제 설명**

# %% [markdown]
# - 정수 `num1`, `num2`가 매개변수 주어집니다.
# - `num1`과 `num2`를 곱한 값을 return 하도록 solution 함수를 완성해주세요.

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 제한사항**

# %% [markdown]
# - 0 ≤ `num1` ≤ 100
# - 0 ≤ `num2` ≤ 100

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 입출력 예**

# %% [markdown]
# |num1|num2|result|
# |:--:|:--:|:--:|
# |3|4|12|
# |27|19|513|

# %% [markdown]
# - **예제 #1**
#
# > `num1`이 3, `num2`가 4이므로 3 * 4 = 12를 return합니다.

# %% [markdown]
# - **예제 #2**
#
# > `num1`이 27 `num2`가 19이므로 27 * 19 = 513를 return합니다.

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 문제 풀이**

# %% [markdown]
# - **풀이 #1**

# %%
def solution(num1, num2):
        return num1 * num2

# %%
solution(3, 4)
# Out:
# 12

# %% [markdown]
# - **풀이 #2**

# %%
solution = lambda num1, num2 : num1 * num2

# %%
solution(3, 4)
# Out:
# 12
