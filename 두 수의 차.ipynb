# %% [markdown]
# ### **🔖 두 수의 차**

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 문제 설명**

# %% [markdown]
# 정수 `num1`과 `num2`가 주어질 때, `num1`에서 `num2`를 뺀 값을 return하도록 soltuion 함수를 완성해주세요.

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 제한사항**

# %% [markdown]
# - -50000 ≤ num1 ≤ 50000
# - -50000 ≤ num2 ≤ 50000

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 입출력 예**

# %% [markdown]
# |num1|num2|result|
# |:--:|:--:|:--:|
# |2|3|-1|
# |100|2|98|

# %% [markdown]
# > **입출력 예 #1**<p>`num1`이 2이고 `num2`가 3이므로 2 - 3 = -1을 return합니다.

# %% [markdown]
# > **입출력 예 #2**<p>`num1`이 100이고 `num2`가 2이므로 100 - 2 = 98을 return합니다.

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 풀이**

# %% [markdown]
# **풀이 01**

# %%
def solution(num1, num2):
    return num1 - num2

# %%
solution(2, 3)
# Out:
# -1

# %% [markdown]
# **풀이 02**

# %%
solution = lambda num1, num2 : num1 - num2

# %%
solution(2, 3)
# Out:
# -1
