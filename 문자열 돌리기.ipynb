# %% [markdown]
# ### **🔖 문자열 돌리기**

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 문제 설명**

# %% [markdown]
# - 문자열 `str`이 주어집니다.
# - 문자열을 시계방향으로 90도 돌려서 아래 입출력 예와 같이 출력하는 코드를 작성해 보세요.

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 제한사항**

# %% [markdown]
# - 1 ≤ `str`의 길이 ≤ 10

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 입출력 예**

# %% [markdown]
# - **예제 #1**
#
# > **입력**
# > abcde
#
# > **출력**
# > a
# > b
# > c
# > d
# > e

# %% [markdown]
# ---

# %% [markdown]
# #### **🔻 문제 풀이**

# %% [markdown]
# - **풀이 #1**

# %%
for i in input():
    print(i)
# Out:
# abcde
# a
# b
# c
# d
# e

# %% [markdown]
# - **풀이 #2**

# %%
print("\n".join(input()))
# Out:
# abcde
# a
# b
# c
# d
# e
